# %% [markdown]
# <a href="https://colab.research.google.com/github/Colette-c/MAT-422/blob/main/2_4_Maximum_likelihood_estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLE for Random Samples
#
# Maximum likelihood estimation(MLE) is used to used to estimate parameters of a probability distribution by maximizing a likelihood function.
#
# Let $X_1, X_2, ..., X_n$ have joint pmf or pdf $$f(x_1,x_2,...,x_n;\theta _1, ...,\theta_m)$$ where the parameters $\theta_1,...,\theta_m$ have unknown values. When $x_1,...,x_n$ are the observed sample values and $f$ is regared as a function of $\theta_1,...,\theta_,$, it is called the **likelihood function**.
#
# The maximum likelihood estimates (mle's) $\hat{\theta}_1,...,\hat{\theta}_m$ are those values of the $\theta_i$'s that maximize the likelihood function, so that $$f(x_1,...,x_n;\hat{\theta}_1,...,\hat{\theta}_m)\ge f(x_1,...,x_n;\theta_1,...,\theta_m) \ \ \ \text{for all} \ \ \theta_1,..., \theta_m$$
#
# Note: The **maximum likelihood estimators** are the result of substituting $X_i$'s in place of $x_i$'s.

# %% [markdown]
# # Linear Regression
#
# The process of finding a line of best fit for a set of $(x_i,y_i)$ starts with finding coefficients $\beta_j, j=1,...,p$'s that minimizes: $$\sum_{i=1}^{n}(y_i-\hat{y}_i)^2,$$ where $$\hat{y}_i=\beta_0+\beta_1x_{i1}+...+\beta_px_{ip}$$

# %%
##Using python functions to estimate coefficients for the line of best fit.

import numpy as np
import seaborn as sns

#start with a normal distribution
X=np.linspace(-10,10,n)
b=np.random.normal(0,5,n)
Y=2*x + b

##using the same data set as before
b0, b1 = np.polyfit(X,b,1)

y_estimate = b1 + b0*X

sns.regplot(x=X,y=Y)
# Out:
# <Axes: >
